# %% [markdown]
# ## Import Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import h5py
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import pywt
print(torch.__version__)  
print(torch.cuda.is_available())
# Out:
# 2.11.0+cpu
# False

# %% [markdown]
# ## WaveLets Pre-Processing

# %%
def wavelet_transform(signal, wavelet='coif4', level=3):
    transformed_signal = np.zeros_like(signal, dtype=np.float32)

    for index in range(signal.shape[0]):
        real_part = signal[index, :, 0]
        imag_part = signal[index, :, 1]

        complex_signal = real_part + 1j * imag_part

        coeffs = pywt.wavedec(complex_signal, wavelet, level=level)

        flat_coeffs = np.concatenate([c.flatten() for c in coeffs])


        if len(flat_coeffs) > 1024:
            approx_coeffs = flat_coeffs[:1024]
        elif len(approx_coeffs) < 1024:
            approx_coeffs = np.pad(flat_coeffs, (0, 1024 - len(flat_coeffs)), mode='constant')

        transformed_signal[index, :, 0] = approx_coeffs.real + real_part
        transformed_signal[index, :, 1] = approx_coeffs.imag + imag_part

    return transformed_signal

# %% [markdown]
# ## Data Processing

# %%
class H5Dataset(Dataset):
    def __init__(self, file_list, idx, transform=None):
        self.data = []
        self.labels = []
        self.snr = []
        for file in file_list:
            with h5py.File(file, 'r') as f:
                self.data.append(wavelet_transform(f['X'][:][idx]))
                self.labels.append(f['Y'][:][idx])
                self.snr.append(f['Z'][:][idx])
        self.data = np.vstack(self.data)
        self.labels = np.vstack(self.labels)
        self.snr = np.vstack(self.snr)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        x = self.data[idx]
        y = self.labels[idx]
        z = self.snr[idx]
        return torch.tensor(x, dtype=torch.float32), torch.tensor(y, dtype=torch.float32), torch.tensor(z, dtype=torch.float32)

# %% [markdown]
# ## Model Definition

# %%
class MultiHeadSelfAttention(nn.Module):
    def __init__(self, embed_dim, num_heads=8):

        super(MultiHeadSelfAttention, self).__init__()
        for layer in self.modules():
            if isinstance(layer, nn.Linear):
                torch.nn.init.xavier_uniform_(layer.weight)
                if layer.bias is not None:
                    torch.nn.init.zeros_(layer.bias)
            elif isinstance(layer, nn.Conv2d):
                torch.nn.init.xavier_uniform_(layer.weight)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        if embed_dim % num_heads != 0:
            raise ValueError(
                f"embedding dimension = {embed_dim} should be divisible by number of heads = {num_heads}"
            )
        self.projection_dim = embed_dim // num_heads

        self.query_dense = nn.Linear(embed_dim, embed_dim, bias=False)
        self.key_dense = nn.Linear(embed_dim, embed_dim, bias=False)
        self.value_dense = nn.Linear(embed_dim, embed_dim, bias=False)
        self.combine_heads = nn.Linear(embed_dim, embed_dim)

    def attention(self, query, key, value):
        score = torch.matmul(query, key.transpose(-2, -1))
        dim_key = torch.tensor(key.shape[-1], dtype=torch.float32)
        scaled_score = score / torch.sqrt(dim_key + 1e-9)
        weights = torch.softmax(scaled_score, dim=-1)
        output = torch.matmul(weights, value)
        return output, weights

    def separate_heads(self, x, batch_size):
        x = x.view(batch_size, -1, self.num_heads, self.projection_dim)
        return x.permute(0, 2, 1, 3)

    def forward(self, inputs):
        batch_size = inputs.shape[0]
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)

        query = self.separate_heads(query, batch_size)
        key = self.separate_heads(key, batch_size)
        value = self.separate_heads(value, batch_size)

        attention, _ = self.attention(query, key, value)
        attention = attention.permute(0, 2, 1, 3).contiguous()
        concat_attention = attention.view(batch_size, -1, self.embed_dim)
        output = self.combine_heads(concat_attention)
        return output

# %%
class TransformerBlock(nn.Module):
    def __init__(self, embed_dim, num_heads, ff_dim, dropout_rate=0.2):
        super(TransformerBlock, self).__init__()
        for layer in self.modules():
            if isinstance(layer, nn.Linear):
                torch.nn.init.xavier_uniform_(layer.weight)
                if layer.bias is not None:
                    torch.nn.init.zeros_(layer.bias)
            elif isinstance(layer, nn.Conv2d):
                torch.nn.init.xavier_uniform_(layer.weight)
        self.att = MultiHeadSelfAttention(embed_dim, num_heads)
        self.ffn = nn.Sequential(
            nn.Linear(embed_dim, ff_dim),
            nn.ReLU(),
            nn.Linear(ff_dim, embed_dim)
        )
        self.layernorm1 = nn.LayerNorm(embed_dim, eps=1e-6)
        self.layernorm2 = nn.LayerNorm(embed_dim, eps=1e-6)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.dropout2 = nn.Dropout(dropout_rate)

    def forward(self, inputs):
        attn_output = self.att(inputs)
        attn_output = self.dropout1(attn_output)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)

# %%
def proposed_model(X_train_shape, num_classes):
    embed_dim = 1024  # Embedding size for each token
    num_heads = 128  # Number of attention heads
    ff_dim = 256  # Hidden layer size in feed forward network inside transformer

    class Model(nn.Module):
      def __init__(self):

        super(Model, self).__init__()
        for layer in self.modules():
            if isinstance(layer, nn.Linear):
                torch.nn.init.xavier_uniform_(layer.weight)
                if layer.bias is not None:
                    torch.nn.init.zeros_(layer.bias)
            elif isinstance(layer, nn.Conv2d):
                torch.nn.init.xavier_uniform_(layer.weight)
        self.reshape = nn.Linear(X_train_shape[-1], 1024*2)
        self.transformer_block = TransformerBlock(embed_dim, num_heads, ff_dim)
        self.global_avg_pool = nn.AdaptiveAvgPool1d(1)
        self.batch_norm = nn.LayerNorm(embed_dim)
        self.dropout1 = nn.Dropout(0.3)
        self.dense1 = nn.Linear(embed_dim, 128)
        self.dropout2 = nn.Dropout(0.2)
        self.dense2 = nn.Linear(128, 128)
        self.dropout3 = nn.Dropout(0.2)
        self.output_layer = nn.Linear(128, num_classes)

      def forward(self, x):
          x = x.view(-1, 2, 1024)
          x = self.transformer_block(x)
          x = self.global_avg_pool(x.transpose(1, 2)).squeeze(-1)
          x = self.batch_norm(x)
          x = self.dropout1(torch.selu(self.dense1(x)))
          x = self.dropout2(torch.selu(self.dense2(x)))
          x = self.dropout3(x)
          x = torch.softmax(self.output_layer(x), dim=-1)
          return x
    return Model()

# %% [markdown]
# ## Model Training

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    for epoch in range(start_epoch, start_epoch + num_epochs):
        model.train()
        train_loss = 0
        correct = 0
        total = 0

        for inputs, labels, snr in train_loader:
            inputs, labels, snr = inputs.to(device), labels.to(device), snr.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += (predicted == labels.max(1)[1]).sum().item()

        train_acc = 100. * correct / total
        train_losses.append(train_loss / total)
        train_accuracies.append(train_acc)

        val_loss, val_acc = evaluate_model(model, val_loader, criterion)
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss / total:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")

        if (epoch + 1) % 5 == 0:
            torch.save({
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict()
            }, f"checkpoint_epoch_{epoch+1}.pth")

            print(f"Model saved at epoch {epoch+1}")
            
    # Plotting Loss and Accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss')
    plt.plot(range(1, num_epochs + 1), val_losses, label='Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss Curve')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(1, num_epochs + 1), train_accuracies, label='Train Accuracy')
    plt.plot(range(1, num_epochs + 1), val_accuracies, label='Val Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy Curve')
    plt.legend()

    plt.tight_layout()
    plt.show()

def evaluate_model(model, val_loader, criterion):
  model.eval()
  val_loss = 0
  correct = 0
  total = 0
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  with torch.no_grad():
      for inputs, labels, snr in val_loader:
          inputs, labels, snr = inputs.to(device), labels.to(device), snr.to(device)
          outputs = model(inputs)
          loss = criterion(outputs, labels)
          val_loss += loss.item() * inputs.size(0)
          _, predicted = outputs.max(1)
          total += labels.size(0)
          correct += (predicted == labels.max(1)[1]).sum().item()

  val_loss /= total
  val_acc = 100. * correct / total
  return val_loss, val_acc


def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues, labels=[]):
    plt.figure(figsize=(10, 10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# File paths and dataset split
batch_size = 4096
dir_path =  'ExtractDataset'
f = h5py.File(dir_path + r'/part0.h5')

sample_num = f['X'].shape[0]
file_list = [dir_path + f"/part{i}.h5" for i in range(24)]
idx = np.random.choice(range(0,sample_num),size=60000)

train_size = int(0.8 * len(idx))
train_idx, test_idx = idx[:train_size], idx[train_size:]

train_dataset = H5Dataset(file_list, train_idx)
test_dataset = H5Dataset(file_list, test_idx)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
input_shape = train_dataset[0][0].shape
num_classes = 24
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = proposed_model(input_shape, num_classes).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs=30)
# Out:
# Epoch 1/30, Train Loss: 0.7102, Train Acc: 12.26%, Val Loss: 0.7084, Val Acc: 17.76%
# Epoch 2/30, Train Loss: 0.7078, Train Acc: 18.87%, Val Loss: 0.7072, Val Acc: 20.02%
# Epoch 3/30, Train Loss: 0.7070, Train Acc: 20.65%, Val Loss: 0.7069, Val Acc: 21.20%
# Epoch 4/30, Train Loss: 0.7066, Train Acc: 21.89%, Val Loss: 0.7066, Val Acc: 22.13%
# Epoch 5/30, Train Loss: 0.7063, Train Acc: 22.73%, Val Loss: 0.7064, Val Acc: 22.71%
# Model saved at epoch 5
# Epoch 6/30, Train Loss: 0.7060, Train Acc: 23.47%, Val Loss: 0.7062, Val Acc: 23.13%
# Epoch 7/30, Train Loss: 0.7058, Train Acc: 24.01%, Val Loss: 0.7061, Val Acc: 23.56%
# Epoch 8/30, Train Loss: 0.7056, Train Acc: 24.59%, Val Loss: 0.7060, Val Acc: 23.94%
# Epoch 9/30, Train Loss: 0.7054, Train Acc: 25.35%, Val Loss: 0.7058, Val Acc: 24.48%
# Epoch 10/30, Train Loss: 0.7052, Train Acc: 25.91%, Val Loss: 0.7058, Val Acc: 24.73%
# Model saved at epoch 10
# Epoch 11/30, Train Loss: 0.7051, Train Acc: 26.39%, Val Loss: 0.7056, Val Acc: 25.24%
# Epoch 12/30, Train Loss: 0.7049, Train Acc: 27.02%, Val Loss: 0.7055, Val Acc: 25.61%
# Epoch 13/30, Train Loss: 0.7046, Train Acc: 27.74%, Val Loss: 0.7053, Val Acc: 26.26%
# Epoch 14/30, Train Loss: 0.7044, Train Acc: 28.24%, Val Loss: 0.7051, Val Acc: 26.56%
# Epoch 15/30, Train Loss: 0.7042, Train Acc: 28.90%, Val Loss: 0.7049, Val Acc: 27.27%
# Model saved at epoch 15
# Epoch 16/30, Train Loss: 0.7040, Train Acc: 29.55%, Val Loss: 0.7047, Val Acc: 27.70%
# Epoch 17/30, Train Loss: 0.7038, Train Acc: 30.10%, Val Loss: 0.7047, Val Acc: 27.88%
# Epoch 18/30, Train Loss: 0.7036, Train Acc: 30.88%, Val Loss: 0.7044, Val Acc: 28.62%
# Epoch 19/30, Train Loss: 0.7033, Train Acc: 31.57%, Val Loss: 0.7042, Val Acc: 29.22%
# Epoch 20/30, Train Loss: 0.7030, Train Acc: 32.45%, Val Loss: 0.7040, Val Acc: 29.97%
# Model saved at epoch 20
# Epoch 21/30, Train Loss: 0.7029, Train Acc: 33.04%, Val Loss: 0.7039, Val Acc: 30.23%
# Epoch 22/30, Train Loss: 0.7027, Train Acc: 33.77%, Val Loss: 0.7038, Val Acc: 30.85%
# Epoch 23/30, Train Loss: 0.7025, Train Acc: 34.49%, Val Loss: 0.7038, Val Acc: 31.19%
# Epoch 24/30, Train Loss: 0.7022, Train Acc: 35.56%, Val Loss: 0.7035, Val Acc: 32.22%
# Epoch 25/30, Train Loss: 0.7019, Train Acc: 36.90%, Val Loss: 0.7032, Val Acc: 33.57%
# Model saved at epoch 25
# Epoch 26/30, Train Loss: 0.7015, Train Acc: 38.41%, Val Loss: 0.7031, Val Acc: 34.14%
# Epoch 27/30, Train Loss: 0.7011, Train Acc: 39.73%, Val Loss: 0.7029, Val Acc: 35.11%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 10
#       7 optimizer = optim.Adam(model.parameters(), lr=0.0001)
#       9 # Train and Evaluate
# ---> 10 train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs=30)
#
# Cell In[7], line 30, in train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs)
#      27 train_losses.append(train_loss / total)
#      28 train_accuracies.append(train_acc)
# ---> 30 val_loss, val_acc = evaluate_model(model, val_loader, criterion)
#      31 val_losses.append(val_loss)
#      32 val_accuracies.append(val_acc)
#
# Cell In[7], line 73, in evaluate_model(model, val_loader, criterion)
#      71 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      72 with torch.no_grad():
# ---> 73     for inputs, labels, snr in val_loader:
#      74         inputs, labels, snr = inputs.to(device), labels.to(device), snr.to(device)
#      75         outputs = model(inputs)
#
# File ~\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File ~\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:801, in _SingleProcessDataLoaderIter._next_data(self)
#     799 def _next_data(self):
#     800     index = self._next_index()  # may raise StopIteration
# --> 801     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802     if self._pin_memory:
#     803         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\anaconda3\Lib\site-packages\torch\utils\data\_utils\fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
# ---> 54         data = [self.dataset[idx] for idx in possibly_batched_index]
#      55 else:
#      56     data = self.dataset[possibly_batched_index]
#
# Cell In[3], line 23, in H5Dataset.__getitem__(self, idx)
#      21 y = self.labels[idx]
#      22 z = self.snr[idx]
# ---> 23 return torch.tensor(x, dtype=torch.float32), torch.tensor(y, dtype=torch.float32), torch.tensor(z, dtype=torch.float32)
#
# KeyboardInterrupt:

# %%
checkpoint = torch.load("checkpoint_epoch_45.pth")

model = proposed_model(input_shape, num_classes)
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
criterion = nn.BCEWithLogitsLoss()

start_epoch = checkpoint['epoch']
print(f"Resuming from epoch {start_epoch}")
# Out:
# Resuming from epoch 45

# %%
train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs=100)
# Out:
# Epoch 46/100, Train Loss: 0.6982, Train Acc: 49.15%, Val Loss: 0.6977, Val Acc: 50.19%
# Epoch 47/100, Train Loss: 0.6978, Train Acc: 50.00%, Val Loss: 0.6975, Val Acc: 50.67%
# Epoch 48/100, Train Loss: 0.6975, Train Acc: 50.82%, Val Loss: 0.6974, Val Acc: 50.97%
# Epoch 49/100, Train Loss: 0.6973, Train Acc: 51.34%, Val Loss: 0.6973, Val Acc: 51.28%
# Epoch 50/100, Train Loss: 0.6971, Train Acc: 51.85%, Val Loss: 0.6971, Val Acc: 51.56%
# Model saved at epoch 50
# Epoch 51/100, Train Loss: 0.6968, Train Acc: 52.36%, Val Loss: 0.6970, Val Acc: 51.97%
# Epoch 52/100, Train Loss: 0.6967, Train Acc: 52.71%, Val Loss: 0.6970, Val Acc: 51.82%
# Epoch 53/100, Train Loss: 0.6967, Train Acc: 52.78%, Val Loss: 0.6970, Val Acc: 51.88%
# Epoch 54/100, Train Loss: 0.6965, Train Acc: 53.17%, Val Loss: 0.6969, Val Acc: 52.06%
# Epoch 55/100, Train Loss: 0.6964, Train Acc: 53.44%, Val Loss: 0.6969, Val Acc: 52.20%
# Model saved at epoch 55
# Epoch 56/100, Train Loss: 0.6963, Train Acc: 53.72%, Val Loss: 0.6967, Val Acc: 52.62%
# Epoch 57/100, Train Loss: 0.6961, Train Acc: 54.06%, Val Loss: 0.6966, Val Acc: 52.65%
# Epoch 58/100, Train Loss: 0.6960, Train Acc: 54.33%, Val Loss: 0.6966, Val Acc: 52.75%
# Epoch 59/100, Train Loss: 0.6959, Train Acc: 54.59%, Val Loss: 0.6967, Val Acc: 52.63%
# Epoch 60/100, Train Loss: 0.6958, Train Acc: 54.75%, Val Loss: 0.6965, Val Acc: 52.92%
# Model saved at epoch 60
# Epoch 61/100, Train Loss: 0.6957, Train Acc: 55.02%, Val Loss: 0.6965, Val Acc: 52.84%
# Epoch 62/100, Train Loss: 0.6956, Train Acc: 55.21%, Val Loss: 0.6965, Val Acc: 52.97%
# Epoch 63/100, Train Loss: 0.6956, Train Acc: 55.25%, Val Loss: 0.6965, Val Acc: 52.90%
# Epoch 64/100, Train Loss: 0.6955, Train Acc: 55.47%, Val Loss: 0.6964, Val Acc: 53.06%
# Epoch 65/100, Train Loss: 0.6954, Train Acc: 55.71%, Val Loss: 0.6964, Val Acc: 53.13%
# Model saved at epoch 65
# Epoch 66/100, Train Loss: 0.6954, Train Acc: 55.78%, Val Loss: 0.6965, Val Acc: 52.93%
# Epoch 67/100, Train Loss: 0.6953, Train Acc: 55.98%, Val Loss: 0.6963, Val Acc: 53.28%
# Epoch 68/100, Train Loss: 0.6952, Train Acc: 56.12%, Val Loss: 0.6964, Val Acc: 53.16%
# Epoch 69/100, Train Loss: 0.6951, Train Acc: 56.33%, Val Loss: 0.6963, Val Acc: 53.35%
# Epoch 70/100, Train Loss: 0.6950, Train Acc: 56.53%, Val Loss: 0.6962, Val Acc: 53.55%
# Model saved at epoch 70
# Epoch 71/100, Train Loss: 0.6950, Train Acc: 56.59%, Val Loss: 0.6962, Val Acc: 53.41%
# Epoch 72/100, Train Loss: 0.6949, Train Acc: 56.76%, Val Loss: 0.6963, Val Acc: 53.17%
# Epoch 73/100, Train Loss: 0.6949, Train Acc: 56.77%, Val Loss: 0.6962, Val Acc: 53.41%
# Epoch 74/100, Train Loss: 0.6948, Train Acc: 57.02%, Val Loss: 0.6962, Val Acc: 53.33%
# Epoch 75/100, Train Loss: 0.6947, Train Acc: 57.21%, Val Loss: 0.6961, Val Acc: 53.68%
# Model saved at epoch 75
# Epoch 76/100, Train Loss: 0.6946, Train Acc: 57.50%, Val Loss: 0.6961, Val Acc: 53.63%
# Epoch 77/100, Train Loss: 0.6945, Train Acc: 57.66%, Val Loss: 0.6960, Val Acc: 53.87%
# Epoch 78/100, Train Loss: 0.6944, Train Acc: 57.86%, Val Loss: 0.6960, Val Acc: 53.93%
# Epoch 79/100, Train Loss: 0.6944, Train Acc: 58.04%, Val Loss: 0.6960, Val Acc: 53.89%
# Epoch 80/100, Train Loss: 0.6943, Train Acc: 58.23%, Val Loss: 0.6960, Val Acc: 54.03%
# Model saved at epoch 80
# Epoch 81/100, Train Loss: 0.6942, Train Acc: 58.37%, Val Loss: 0.6960, Val Acc: 54.06%
# Epoch 82/100, Train Loss: 0.6942, Train Acc: 58.52%, Val Loss: 0.6959, Val Acc: 54.15%
# Epoch 83/100, Train Loss: 0.6941, Train Acc: 58.68%, Val Loss: 0.6960, Val Acc: 54.16%
# Epoch 84/100, Train Loss: 0.6941, Train Acc: 58.81%, Val Loss: 0.6959, Val Acc: 54.31%
# Epoch 85/100, Train Loss: 0.6940, Train Acc: 59.04%, Val Loss: 0.6959, Val Acc: 54.30%
# Model saved at epoch 85
# Epoch 86/100, Train Loss: 0.6940, Train Acc: 59.07%, Val Loss: 0.6959, Val Acc: 54.23%
# Epoch 87/100, Train Loss: 0.6939, Train Acc: 59.32%, Val Loss: 0.6959, Val Acc: 54.18%
# Epoch 88/100, Train Loss: 0.6939, Train Acc: 59.34%, Val Loss: 0.6958, Val Acc: 54.48%
# Epoch 89/100, Train Loss: 0.6938, Train Acc: 59.58%, Val Loss: 0.6958, Val Acc: 54.59%
# Epoch 90/100, Train Loss: 0.6938, Train Acc: 59.66%, Val Loss: 0.6959, Val Acc: 54.37%
# Model saved at epoch 90
# Epoch 91/100, Train Loss: 0.6937, Train Acc: 59.86%, Val Loss: 0.6957, Val Acc: 54.68%
# Epoch 92/100, Train Loss: 0.6936, Train Acc: 60.05%, Val Loss: 0.6957, Val Acc: 54.79%
# Epoch 93/100, Train Loss: 0.6936, Train Acc: 60.13%, Val Loss: 0.6957, Val Acc: 54.70%
# Epoch 94/100, Train Loss: 0.6935, Train Acc: 60.20%, Val Loss: 0.6957, Val Acc: 54.81%
# Epoch 95/100, Train Loss: 0.6934, Train Acc: 60.40%, Val Loss: 0.6957, Val Acc: 54.69%
# Model saved at epoch 95
# Epoch 96/100, Train Loss: 0.6934, Train Acc: 60.47%, Val Loss: 0.6958, Val Acc: 54.60%

# %%
checkpoint = torch.load("checkpoint_epoch_95.pth")

input_shape = train_dataset[0][0].shape
num_classes = 24
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = proposed_model(input_shape, num_classes)
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
criterion = nn.BCEWithLogitsLoss()

start_epoch = checkpoint['epoch']
print(f"Resuming from epoch {start_epoch}")
# Out:
# Resuming from epoch 95

# %%
train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs=100)
# Out:
# Epoch 96/100, Train Loss: 0.6961, Train Acc: 53.88%, Val Loss: 0.6956, Val Acc: 55.02%
# Epoch 97/100, Train Loss: 0.6956, Train Acc: 55.09%, Val Loss: 0.6952, Val Acc: 55.90%
# Epoch 98/100, Train Loss: 0.6952, Train Acc: 56.08%, Val Loss: 0.6951, Val Acc: 56.21%
# Epoch 99/100, Train Loss: 0.6950, Train Acc: 56.69%, Val Loss: 0.6949, Val Acc: 56.78%
# Epoch 100/100, Train Loss: 0.6947, Train Acc: 57.25%, Val Loss: 0.6948, Val Acc: 56.94%
# Model saved at epoch 100
# Epoch 101/100, Train Loss: 0.6946, Train Acc: 57.63%, Val Loss: 0.6947, Val Acc: 57.16%
# Epoch 102/100, Train Loss: 0.6945, Train Acc: 57.97%, Val Loss: 0.6947, Val Acc: 57.27%
# Epoch 103/100, Train Loss: 0.6944, Train Acc: 58.16%, Val Loss: 0.6948, Val Acc: 57.02%
# Epoch 104/100, Train Loss: 0.6943, Train Acc: 58.36%, Val Loss: 0.6946, Val Acc: 57.45%
# Epoch 105/100, Train Loss: 0.6941, Train Acc: 58.72%, Val Loss: 0.6945, Val Acc: 57.61%
# Model saved at epoch 105
# Epoch 106/100, Train Loss: 0.6941, Train Acc: 58.91%, Val Loss: 0.6945, Val Acc: 57.75%
# Epoch 107/100, Train Loss: 0.6940, Train Acc: 59.03%, Val Loss: 0.6944, Val Acc: 57.84%
# Epoch 108/100, Train Loss: 0.6940, Train Acc: 59.13%, Val Loss: 0.6945, Val Acc: 57.66%
# Epoch 109/100, Train Loss: 0.6939, Train Acc: 59.25%, Val Loss: 0.6945, Val Acc: 57.61%
# Epoch 110/100, Train Loss: 0.6938, Train Acc: 59.40%, Val Loss: 0.6944, Val Acc: 57.92%
# Model saved at epoch 110
# Epoch 111/100, Train Loss: 0.6938, Train Acc: 59.58%, Val Loss: 0.6944, Val Acc: 57.82%
# Epoch 112/100, Train Loss: 0.6937, Train Acc: 59.69%, Val Loss: 0.6944, Val Acc: 57.93%
# Epoch 113/100, Train Loss: 0.6938, Train Acc: 59.59%, Val Loss: 0.6945, Val Acc: 57.62%
# Epoch 114/100, Train Loss: 0.6937, Train Acc: 59.74%, Val Loss: 0.6945, Val Acc: 57.76%
# Epoch 115/100, Train Loss: 0.6936, Train Acc: 59.90%, Val Loss: 0.6944, Val Acc: 57.83%
# Model saved at epoch 115
# Epoch 116/100, Train Loss: 0.6936, Train Acc: 60.04%, Val Loss: 0.6944, Val Acc: 57.85%
# Epoch 117/100, Train Loss: 0.6935, Train Acc: 60.20%, Val Loss: 0.6944, Val Acc: 57.87%
# Epoch 118/100, Train Loss: 0.6935, Train Acc: 60.21%, Val Loss: 0.6944, Val Acc: 57.92%
# Epoch 119/100, Train Loss: 0.6934, Train Acc: 60.50%, Val Loss: 0.6943, Val Acc: 58.05%
# Epoch 120/100, Train Loss: 0.6933, Train Acc: 60.54%, Val Loss: 0.6943, Val Acc: 58.15%
# Model saved at epoch 120
# Epoch 121/100, Train Loss: 0.6933, Train Acc: 60.61%, Val Loss: 0.6943, Val Acc: 58.03%
# Epoch 122/100, Train Loss: 0.6933, Train Acc: 60.71%, Val Loss: 0.6943, Val Acc: 58.19%
# Epoch 123/100, Train Loss: 0.6932, Train Acc: 60.72%, Val Loss: 0.6944, Val Acc: 57.86%
# Epoch 124/100, Train Loss: 0.6932, Train Acc: 60.72%, Val Loss: 0.6943, Val Acc: 57.98%
# Epoch 125/100, Train Loss: 0.6931, Train Acc: 60.98%, Val Loss: 0.6943, Val Acc: 57.99%
# Model saved at epoch 125
# Epoch 126/100, Train Loss: 0.6931, Train Acc: 61.01%, Val Loss: 0.6943, Val Acc: 58.09%
# Epoch 127/100, Train Loss: 0.6931, Train Acc: 61.08%, Val Loss: 0.6942, Val Acc: 58.21%
# Epoch 128/100, Train Loss: 0.6931, Train Acc: 61.11%, Val Loss: 0.6943, Val Acc: 57.95%
# Epoch 129/100, Train Loss: 0.6930, Train Acc: 61.28%, Val Loss: 0.6943, Val Acc: 58.06%
# Epoch 130/100, Train Loss: 0.6930, Train Acc: 61.26%, Val Loss: 0.6943, Val Acc: 58.03%
# Model saved at epoch 130
# Epoch 131/100, Train Loss: 0.6930, Train Acc: 61.21%, Val Loss: 0.6944, Val Acc: 57.77%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs=100)
#
# Cell In[7], line 16, in train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs)
#      14 inputs, labels, snr = inputs.to(device), labels.to(device), snr.to(device)
#      15 optimizer.zero_grad()
# ---> 16 outputs = model(inputs)
#      17 loss = criterion(outputs, labels)
#      18 loss.backward()
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# Cell In[6], line 31, in proposed_model.<locals>.Model.forward(self, x)
#      29 def forward(self, x):
#      30     x = x.view(-1, 2, 1024)
# ---> 31     x = self.transformer_block(x)
#      32     x = self.global_avg_pool(x.transpose(1, 2)).squeeze(-1)
#      33     x = self.batch_norm(x)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# Cell In[5], line 26, in TransformerBlock.forward(self, inputs)
#      24 attn_output = self.dropout1(attn_output)
#      25 out1 = self.layernorm1(inputs + attn_output)
# ---> 26 ffn_output = self.ffn(out1)
#      27 ffn_output = self.dropout2(ffn_output)
#      28 return self.layernorm2(out1 + ffn_output)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
checkpoint = torch.load("checkpoint_epoch_130.pth")

model = proposed_model(input_shape, num_classes)
model.load_state_dict(checkpoint['model_state_dict'])

torch.save(model.state_dict(), "final_model.pth")

print("Final model saved!")
# Out:
# Final model saved!

# %% [markdown]
# ## Confusion Matrix

# %%
y_true = []
y_pred = []
outputs_test = []
model.eval()
with torch.no_grad():
    for inputs, labels , snr in test_loader:
        inputs, labels, snr = inputs.to(device), labels.to(device), snr.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        outputs_test.extend(outputs.cpu().numpy())
        y_true.extend(labels.max(1)[1].cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

classes=["32PSK", "16APSK", "32QAM", "FM", "GMSK", "32APSK", "OQPSK", "8ASK", "BPSK", "8PSK", "AM-SSB-SC", "4ASK", "16PSK", "64APSK", "128QAM", "128APSK", "AM-DSB-SC", "AM-SSB-WC", "64QAM", "QPSK", "256QAM", "AM-DSB-WC", "OOK", "16QAM"]
conf = np.zeros([len(classes),len(classes)])
confnorm = np.zeros([len(classes),len(classes)])
outputs_test= np.array(outputs_test)
for i in range(0, len(test_dataset)):
    j = list(test_dataset.labels[i,:]).index(1)
    k = int(np.argmax(outputs_test[i,:]))
    conf[j,k] = conf[j,k] + 1
for i in range(0,len(classes)):
    confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
plot_confusion_matrix(confnorm, labels=classes)
# plot_confusion_matrix(y_true, y_pred, classes=["32PSK", "16APSK", "32QAM", "FM", "GMSK", "32APSK", "OQPSK", "8ASK", "BPSK", "8PSK", "AM-SSB-SC", "4ASK", "16PSK", "64APSK", "128QAM", "128APSK", "AM-DSB-SC", "AM-SSB-WC", "64QAM", "QPSK", "256QAM", "AM-DSB-WC", "OOK", "16QAM"])

# %% [markdown]
# ## Modulation accuracy

# %%
for i in range(len(confnorm)):
    print(classes[i],confnorm[i,i])
# Out:
# 32PSK 0.8484166666666667
# 16APSK 0.7784166666666666
# 32QAM 0.7171666666666666
# FM 0.5361666666666667
# GMSK 0.7405833333333334
# 32APSK 0.5070833333333333
# OQPSK 0.6823333333333333
# 8ASK 0.7353333333333333
# BPSK 0.3149166666666667
# 8PSK 0.7314166666666667
# AM-SSB-SC 0.3775
# 4ASK 0.4216666666666667
# 16PSK 0.3314166666666667
# 64APSK 0.26408333333333334
# 128QAM 0.66625
# 128APSK 0.5505
# AM-DSB-SC 0.47591666666666665
# AM-SSB-WC 0.5199166666666667
# 64QAM 0.49341666666666667
# QPSK 0.8204166666666667
# 256QAM 0.6135
# AM-DSB-WC 0.8635
# OOK 0.42325
# 16QAM 0.5841666666666666

# %% [markdown]
# ## SNR accuracy

# %%
acc={}
SNRs = range(-20, 31, 2)
outputs_test = []
y_true = []
y_pred = []
model.eval()

for snr in SNRs:
    with torch.no_grad():
        for inputs, labels, snr_dataset in test_loader:
            inputs, labels, snr_dataset = inputs.to(device), labels.to(device), snr_dataset.to(device)
            indices = torch.where(snr_dataset == snr)
            X_test_snr = inputs[indices[0],:,:]
            Y_test_snr = labels[indices[0],:]
            outputs = model(X_test_snr)
            _, predicted = outputs.max(1)
            y_true.extend(Y_test_snr.max(1)[1].cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    conf = np.zeros([len(classes), len(classes)])
    confnorm = np.zeros([len(classes), len(classes)])

    for i in range(0, len(y_true)):
        j = y_true[i]
        k = y_pred[i]
        conf[j, k] += 1

    for i in range(0, len(classes)):
        confnorm[i, :] = conf[i, :] / np.sum(conf[i, :])

    plt.figure()
    plot_confusion_matrix(confnorm, labels=classes, title=f"ConvNet Confusion Matrix (SNR={snr})")

    cor = np.sum(np.diag(conf))
    ncor = np.sum(conf) - cor
    print(f"Overall Accuracy {snr}: ", cor / (cor + ncor))
    acc[snr] = cor / (cor + ncor)
    y_true = []
    y_pred = []
# Out:
# Overall Accuracy -20:  0.4877675840978593
# Overall Accuracy -18:  0.4905642750373692
# Overall Accuracy -16:  0.4969902182091798
# Overall Accuracy -14:  0.5189631176061239
# Overall Accuracy -12:  0.5352784134248665
# Overall Accuracy -10:  0.5757660687593423
# Overall Accuracy -8:  0.6215967623252392
# Overall Accuracy -6:  0.6392045454545454
# Overall Accuracy -4:  0.649077868852459
# Overall Accuracy -2:  0.6307560137457044
# C:\Users\V.Niharika\AppData\Local\Temp\ipykernel_21456\3642233327.py:31: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# Overall Accuracy 0:  0.6152862985685071
# Overall Accuracy 2:  0.6232007575757575
# Overall Accuracy 4:  0.6234832262669522
# Overall Accuracy 6:  0.6022970085470085
# Overall Accuracy 8:  0.6070921985815603
# Overall Accuracy 10:  0.5817867540029112
# Overall Accuracy 12:  0.5790506780870807
# Overall Accuracy 14:  0.5829484218629715
# Overall Accuracy 16:  0.5854210160055672
# Overall Accuracy 18:  0.5907770515613653
# Overall Accuracy 20:  0.595112517580872
# Overall Accuracy 22:  0.5815288713910761
# Overall Accuracy 24:  0.5789373088685015
# Overall Accuracy 26:  0.5770609318996416
# Overall Accuracy 28:  0.5892338416848221
# Overall Accuracy 30:  0.5825599381283836

# %%
plt.figure(figsize=(8,6))
plt.plot(acc.keys(),acc.values(),linewidth=4,color='lightgreen', marker='D', markeredgecolor='black')
plt.ylim(0, 1)
plt.ylabel('Accuracy')
plt.xlabel('SNR')
plt.title('Transformer')
plt.tight_layout()
plt.legend(['Transformer'],loc='upper left')
plt.show()
